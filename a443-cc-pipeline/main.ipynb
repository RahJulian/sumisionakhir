# %%
# %run C:\Users\asus\a443-cc-pipeline\local_pipeline.py
# Out:
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Pipeline root set to: output\Stroke_prediction
# INFO:absl:Generating ephemeral wheel package for 'C:\\Users\\asus\\a443-cc-pipeline\\modules\\transform.py' (including modules: ['components', 'pipeline', 'trainer', 'transform', 'tuner']).
# INFO:absl:User module package has hash fingerprint version 4b9beca0428a6fb9a686556a08a851a05c83c62db3d9d1856b220cf0d6cc4bd1.
# INFO:absl:Executing: ['C:\\Users\\asus\\anaconda3\\envs\\a443-churn\\python.exe', 'C:\\Users\\asus\\AppData\\Local\\Temp\\tmp84ao8j08\\_tfx_generated_setup.py', 'bdist_wheel', '--bdist-dir', 'C:\\Users\\asus\\AppData\\Local\\Temp\\tmpr5di1p_3', '--dist-dir', 'C:\\Users\\asus\\AppData\\Local\\Temp\\tmpuv_s6ye6']
# Training module: modules/trainer.py
# Training steps: 5000
# Eval steps: 1000
# ...
